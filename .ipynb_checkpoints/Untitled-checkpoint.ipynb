# %% [markdown]
# Feature Analysis
# ===========================
#
# The standard features: LLR (low level discriptors)
# File path: \emotiondetection\features_labels_lld

# %%
import numpy as np
import os

def load_data():
    
    lld_dir='./Data/features_labels_lld/lld/train/'
    for name in os.listdir(lld_dir):
        lld_name=lld_dir+name
        lld=np.loadtxt(open(lld_name,'rb'),delimiter=',')
        print lld.shape
    
load_data()
# Out:
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# (384L,)
# ...
